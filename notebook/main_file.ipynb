# %% [markdown]
# See the information of all Dataframes

# %%
import pandas as pd
import glob
import os
processed_folder = "../data/processed"
files = glob.glob(os.path.join(processed_folder, "*.csv"))
dataframes=[]
for f in files:
    name=os.path.basename(f)
    dataframes.append(name)
    dfname=name
    dfname=pd.read_csv(f)
    print("------Number of rows and columns-----" )
    print(name,dfname.shape)
    print("----Null DATA-----")
    print(dfname.isnull().sum())
    print("***************")
# Out:
# ------Number of rows and columns-----
# away_team.csv (24203, 19)
# ----Null DATA-----
# match_id             0
# name                 0
# slug                 0
# gender              33
# user_count           0
# residence        17185
# birthplace       10308
# height           10665
# weight           17293
# plays            12244
# turned_pro       19476
# current_prize      226
# total_prize        133
# player_id            0
# current_rank       325
# name_code            0
# country              5
# full_name            0
# date                 0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# away_team_score.csv (35053, 15)
# ----Null DATA-----
# match_id                  0
# current_score          3013
# display_score          3013
# period_1               3026
# period_2               3346
# period_3              26246
# period_4              35053
# period_5              35053
# period_1_tie_break    32509
# period_2_tie_break    32668
# period_3_tie_break    34403
# period_4_tie_break    35053
# period_5_tie_break    35053
# normal_time           35053
# date                      0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# event.csv (35053, 11)
# ----Null DATA-----
# match_id                    0
# first_to_serve          12504
# home_team_seed          25009
# away_team_seed          25170
# custom_id                   0
# winner_code              3049
# default_period_count        0
# start_datetime              0
# match_slug                  0
# final_result_only           0
# date                        0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# home_team.csv (25610, 19)
# ----Null DATA-----
# match_id             0
# name                 0
# slug                 0
# gender              35
# user_count           0
# residence        18423
# birthplace       10836
# height           11287
# weight           18578
# plays            13126
# turned_pro       20806
# current_prize      130
# total_prize         69
# player_id            0
# current_rank       273
# name_code            0
# country              9
# full_name            0
# date                 0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# home_team_score.csv (35164, 15)
# ----Null DATA-----
# match_id                  0
# current_score          3014
# display_score          3014
# period_1               3026
# period_2               3357
# period_3              26322
# period_4              35164
# period_5              35164
# period_1_tie_break    32610
# period_2_tie_break    32771
# period_3_tie_break    34513
# period_4_tie_break    35164
# period_5_tie_break    35164
# normal_time           35164
# date                      0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# odds.csv (60946, 12)
# ----Null DATA-----
# match_id                       0
# market_id                      0
# market_name                    0
# is_live                        0
# suspended                      0
# initial_fractional_value       0
# fractional_value               0
# choice_name                    0
# choice_source_id               0
# winnig                      3900
# change                         0
# date                           0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# point_by_point.csv (2549369, 14)
# ----Null DATA-----
# match_id             0
# set_id               0
# game_id              0
# point_id             0
# home_point           0
# away_point           0
# point_description    0
# home_point_type      0
# away_point_type      0
# home_score           0
# away_score           0
# serving              0
# scoring              0
# date                 0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# round.csv (19283, 6)
# ----Null DATA-----
# match_id             0
# round_id             0
# name                 0
# slug                 0
# cup_round_type    2627
# date                 0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# season.csv (35671, 5)
# ----Null DATA-----
# match_id     0
# season_id    0
# name         0
# year         0
# date         0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# statistics.csv (1358234, 14)
# ----Null DATA-----
# match_id                        0
# period                          0
# statistic_category_name         0
# statistic_name                  0
# home_stat                       0
# away_stat                       0
# compare_code                    0
# statistic_type                  0
# value_type                      0
# home_value                      0
# away_value                      0
# home_total                 824739
# away_total                 824739
# date                            0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# tennis_power.csv (469677, 6)
# ----Null DATA-----
# match_id          0
# set_num           0
# game_num          0
# value             0
# break_occurred    0
# date              0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# time.csv (35671, 8)
# ----Null DATA-----
# match_id                              0
# period_1                          13095
# period_2                          13200
# period_3                          28785
# period_4                          35671
# period_5                          35671
# current_period_start_timestamp    12545
# date                                  0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# tournament.csv (35671, 17)
# ----Null DATA-----
# match_id                               0
# tournament_id                          0
# tournament_name                        0
# tournament_slug                        0
# tournament_unique_id               35671
# tournament_category_name               0
# tournament_category_slug               0
# user_count                             0
# ground_type                          562
# tennis_points                      31667
# has_event_player_statistics            0
# crowd_sourcing_enabled                 0
# has_performance_graph_feature          0
# display_inverse_home_away_teams        0
# priority                               0
# competition_type                     485
# date                                   0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# venue.csv (35423, 6)
# ----Null DATA-----
# match_id      0
# city        159
# stadium       0
# venue_id      0
# country     159
# date          0
# dtype: int64
# ***************
# ------Number of rows and columns-----
# votes.csv (35658, 4)
# ----Null DATA-----
# match_id     0
# home_vote    0
# away_vote    0
# date         0
# dtype: int64
# ***************
